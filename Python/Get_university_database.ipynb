# %%
import pandas as pd

# %%
# Load the file with semicolon as separator
file_path = 'alumni_u8.csv'  # replace with the actual path
data = pd.read_csv(file_path, sep=';', encoding='utf-8')
data.head()
# Out:
#    Unnamed: 0     name    surname              univ faculty  year        lat  \
# 0           0   Индира   Абзалова  Brown University     NaN  2021  41.818640
# 1           1   Марина    Ажимова           НИУ ВШЭ     NaN  2021  55.806751
# 2           2     Олег  Андриенко   Yale University     NaN  2021  41.257131
# 3           3    Алина   Антипина           РАНХиГС     NaN  2021  55.737857
# 4           4  Георгий    Асатрян           НИУ ВШЭ     NaN  2021  55.806751
#
#          lon study_form spec_sub          city                 region
# 0 -71.408801        NaN      NaN        Казань          Пермский край
# 1  37.541893        NaN      NaN        Москва                 Москва
# 2 -72.989670        NaN      NaN        Москва                 Москва
# 3  37.603312        NaN      NaN  Северодвинск  Архангельская область
# 4  37.541893        NaN      NaN        Москва                 Москва

# %%
# # Select only relevant columns (assuming they are named something like 'univ', 'lat', 'lon')
university_data = data[['univ', 'lat', 'lon']].drop_duplicates()

# # Save to a new CSV file
university_data.to_csv('universities_with_coordinates.csv', index=False)
